# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Load Data
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# Extract IDs for submission
test_ids = test['id']

# Prepare Data
def preprocess_data(df):
    df = df.copy()
    
    # Label Encode categorical features (for training purposes)
    cat_features = ['person_home_ownership', 'loan_intent', 'loan_grade']
    for col in cat_features:
        le = LabelEncoder()
        df[col] = le.fit_transform(df[col])
    
    # Label encode 'cb_person_default_on_file' since it is categorical (it is still a string column)
    le_default = LabelEncoder()
    df['cb_person_default_on_file'] = le_default.fit_transform(df['cb_person_default_on_file'])
    
    # Fill missing values with a specific value (for instance, -999)
    df.fillna(-999, inplace=True)
    
    return df

train = preprocess_data(train)
test = preprocess_data(test)

# One-hot encode categorical features using pandas get_dummies
cat_columns = ['person_home_ownership', 'loan_intent', 'loan_grade']

# One-Hot Encoding (drop_first=True to avoid multicollinearity)
train = pd.get_dummies(train, columns=cat_columns, drop_first=True)
test = pd.get_dummies(test, columns=cat_columns, drop_first=True)

# Ensure both train and test have the same columns after one-hot encoding
#train, test = train.align(test, join='left', axis=1)

# Fill any NaN values created by alignment (in case some categories are missing in the test set)
train.fillna(0, inplace=True)
test.fillna(0, inplace=True)

# Drop 'id' and target column 'loan_status' from the training set
X = train.drop(columns=['id', 'loan_status'])
y = train['loan_status']
X_test = test.drop(columns=['id'])  # No 'loan_status' column in the test set

# Standardize numeric features (after one-hot encoding)
scaler = StandardScaler()
X = scaler.fit_transform(X)  # Apply scaling to training data
X_test = scaler.transform(X_test)  # Apply the same scaling to test data

# Cross-Validation
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)

# Models
models = {
    'LightGBM': LGBMClassifier(n_estimators=1000, learning_rate=0.01, random_state=42),
    'XGBoost': XGBClassifier(n_estimators=1000, learning_rate=0.01, eval_metric='logloss', random_state=42),
    'CatBoost': CatBoostClassifier(iterations=1000, learning_rate=0.01, verbose=0, random_state=42)
}

# Training and Prediction
predictions = np.zeros((X_test.shape[0], len(models)))
meta_features = np.zeros((X.shape[0], len(models)))

for i, (model_name, model) in enumerate(models.items()):
    print(f'Training {model_name}...')
    fold_predictions = np.zeros(X_test.shape[0])
    fold_meta_features = np.zeros(X.shape[0])
    
    for fold, (train_idx, val_idx) in enumerate(cv.split(X, y)):
        print(f'Fold {fold+1}/{n_splits}')
        X_train, X_val = X[train_idx], X[val_idx]
        y_train, y_val = y.iloc[train_idx], y.iloc[val_idx]
        
        if model_name == 'LightGBM':
            # For LightGBM, apply early stopping properly
            model.fit(X_train, y_train, eval_set=[(X_val, y_val)])
        else:
            model.fit(X_train, y_train)
        
        fold_meta_features[val_idx] = model.predict_proba(X_val)[:, 1]
        fold_predictions += model.predict_proba(X_test)[:, 1] / n_splits
    
    meta_features[:, i] = fold_meta_features
    predictions[:, i] = fold_predictions
    print(f'{model_name} CV AUC: {roc_auc_score(y, fold_meta_features):.4f}')

# Train a meta-model on the stacked features
meta_model = CatBoostClassifier(iterations=1000, learning_rate=0.01, random_state=42)
meta_model.fit(meta_features, y)
meta_predictions = meta_model.predict_proba(predictions)[:, 1]

# Final Predictions
submission = pd.DataFrame({'id': test_ids, 'loan_status': meta_predictions})
submission.to_csv('submission.csv', index=False)

print("Submission file created: submission.csv")
# Out:
# Training LightGBM...
# Fold 1/5
# [LightGBM] [Info] Number of positive: 6680, number of negative: 40236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002614 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 910
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142382 -> initscore=-1.795644
# [LightGBM] [Info] Start training from score -1.795644
# Fold 2/5
# [LightGBM] [Info] Number of positive: 6680, number of negative: 40236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002473 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 909
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142382 -> initscore=-1.795644
# [LightGBM] [Info] Start training from score -1.795644
# Fold 3/5
# [LightGBM] [Info] Number of positive: 6680, number of negative: 40236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002394 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 910
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142382 -> initscore=-1.795644
# [LightGBM] [Info] Start training from score -1.795644
# Fold 4/5
# [LightGBM] [Info] Number of positive: 6680, number of negative: 40236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002494 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 910
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142382 -> initscore=-1.795644
# [LightGBM] [Info] Start training from score -1.795644
# Fold 5/5
# [LightGBM] [Info] Number of positive: 6680, number of negative: 40236
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002434 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 905
# [LightGBM] [Info] Number of data points in the train set: 46916, number of used features: 22
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.142382 -> initscore=-1.795644
# [LightGBM] [Info] Start training from score -1.795644
# LightGBM CV AUC: 0.9569
# Training XGBoost...
# Fold 1/5
# C:\Users\Raul\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:39:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Fold 2/5
# C:\Users\Raul\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:39:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Fold 3/5
# C:\Users\Raul\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:39:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Fold 4/5
# C:\Users\Raul\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:39:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Fold 5/5
# C:\Users\Raul\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [23:39:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# XGBoost CV AUC: 0.9519
# Training CatBoost...
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5
# CatBoost CV AUC: 0.9427
# 0:	learn: 0.6753381	total: 10.6ms	remaining: 10.6s
# 1:	learn: 0.6576542	total: 20.7ms	remaining: 10.3s
# 2:	learn: 0.6411876	total: 31.5ms	remaining: 10.5s
# 3:	learn: 0.6256346	total: 42.3ms	remaining: 10.5s
# 4:	learn: 0.6100254	total: 52.6ms	remaining: 10.5s
# 5:	learn: 0.5960987	total: 64.6ms	remaining: 10.7s
# 6:	learn: 0.5815160	total: 76.1ms	remaining: 10.8s
# 7:	learn: 0.5675095	total: 88ms	remaining: 10.9s
# 8:	learn: 0.5542823	total: 101ms	remaining: 11.1s
# 9:	learn: 0.5418066	total: 112ms	remaining: 11.1s
# 10:	learn: 0.5290206	total: 127ms	remaining: 11.4s
# 11:	learn: 0.5167922	total: 139ms	remaining: 11.4s
# 12:	learn: 0.5048366	total: 151ms	remaining: 11.4s
# 13:	learn: 0.4932757	total: 162ms	remaining: 11.4s
# 14:	learn: 0.4822154	total: 174ms	remaining: 11.4s
# 15:	learn: 0.4715410	total: 189ms	remaining: 11.6s
# 16:	learn: 0.4609051	total: 203ms	remaining: 11.8s
# 17:	learn: 0.4513749	total: 219ms	remaining: 11.9s
# 18:	learn: 0.4416830	total: 231ms	remaining: 11.9s
# 19:	learn: 0.4326159	total: 243ms	remaining: 11.9s
# 20:	learn: 0.4236522	total: 255ms	remaining: 11.9s
# 21:	learn: 0.4155087	total: 267ms	remaining: 11.9s
# 22:	learn: 0.4071450	total: 279ms	remaining: 11.9s
# 23:	learn: 0.3989600	total: 291ms	remaining: 11.8s
# 24:	learn: 0.3912946	total: 304ms	remaining: 11.8s
# 25:	learn: 0.3838447	total: 316ms	remaining: 11.8s
# 26:	learn: 0.3763526	total: 328ms	remaining: 11.8s
# 27:	learn: 0.3692587	total: 340ms	remaining: 11.8s
# 28:	learn: 0.3626894	total: 353ms	remaining: 11.8s
# 29:	learn: 0.3559840	total: 365ms	remaining: 11.8s
# 30:	learn: 0.3499707	total: 379ms	remaining: 11.8s
# 31:	learn: 0.3437664	total: 392ms	remaining: 11.8s
# 32:	learn: 0.3379466	total: 404ms	remaining: 11.8s
# 33:	learn: 0.3324043	total: 415ms	remaining: 11.8s
# 34:	learn: 0.3272754	total: 427ms	remaining: 11.8s
# 35:	learn: 0.3217535	total: 439ms	remaining: 11.7s
# 36:	learn: 0.3165195	total: 451ms	remaining: 11.7s
# 37:	learn: 0.3115833	total: 463ms	remaining: 11.7s
# 38:	learn: 0.3067899	total: 475ms	remaining: 11.7s
# 39:	learn: 0.3021778	total: 487ms	remaining: 11.7s
# 40:	learn: 0.2975981	total: 499ms	remaining: 11.7s
# 41:	learn: 0.2932303	total: 513ms	remaining: 11.7s
# 42:	learn: 0.2894822	total: 526ms	remaining: 11.7s
# 43:	learn: 0.2856700	total: 537ms	remaining: 11.7s
# 44:	learn: 0.2816769	total: 551ms	remaining: 11.7s
# 45:	learn: 0.2780376	total: 564ms	remaining: 11.7s
# 46:	learn: 0.2743222	total: 578ms	remaining: 11.7s
# 47:	learn: 0.2708327	total: 591ms	remaining: 11.7s
# 48:	learn: 0.2675019	total: 603ms	remaining: 11.7s
# 49:	learn: 0.2642910	total: 616ms	remaining: 11.7s
# 50:	learn: 0.2610478	total: 629ms	remaining: 11.7s
# 51:	learn: 0.2581631	total: 642ms	remaining: 11.7s
# 52:	learn: 0.2553636	total: 655ms	remaining: 11.7s
# 53:	learn: 0.2523964	total: 668ms	remaining: 11.7s
# 54:	learn: 0.2494637	total: 680ms	remaining: 11.7s
# 55:	learn: 0.2467018	total: 693ms	remaining: 11.7s
# 56:	learn: 0.2440007	total: 705ms	remaining: 11.7s
# 57:	learn: 0.2415040	total: 717ms	remaining: 11.7s
# 58:	learn: 0.2390469	total: 730ms	remaining: 11.6s
# 59:	learn: 0.2366709	total: 742ms	remaining: 11.6s
# 60:	learn: 0.2342927	total: 755ms	remaining: 11.6s
# 61:	learn: 0.2319932	total: 769ms	remaining: 11.6s
# 62:	learn: 0.2298599	total: 782ms	remaining: 11.6s
# 63:	learn: 0.2276424	total: 795ms	remaining: 11.6s
# 64:	learn: 0.2255784	total: 809ms	remaining: 11.6s
# 65:	learn: 0.2236528	total: 821ms	remaining: 11.6s
# 66:	learn: 0.2216973	total: 832ms	remaining: 11.6s
# 67:	learn: 0.2198420	total: 845ms	remaining: 11.6s
# 68:	learn: 0.2180394	total: 858ms	remaining: 11.6s
# 69:	learn: 0.2163144	total: 871ms	remaining: 11.6s
# 70:	learn: 0.2145449	total: 881ms	remaining: 11.5s
# 71:	learn: 0.2129165	total: 894ms	remaining: 11.5s
# 72:	learn: 0.2113359	total: 906ms	remaining: 11.5s
# 73:	learn: 0.2099249	total: 916ms	remaining: 11.5s
# 74:	learn: 0.2084066	total: 928ms	remaining: 11.4s
# 75:	learn: 0.2070107	total: 939ms	remaining: 11.4s
# 76:	learn: 0.2055647	total: 951ms	remaining: 11.4s
# 77:	learn: 0.2041324	total: 962ms	remaining: 11.4s
# 78:	learn: 0.2027681	total: 974ms	remaining: 11.4s
# 79:	learn: 0.2013937	total: 986ms	remaining: 11.3s
# 80:	learn: 0.2001168	total: 997ms	remaining: 11.3s
# 81:	learn: 0.1988890	total: 1.01s	remaining: 11.3s
# 82:	learn: 0.1976323	total: 1.02s	remaining: 11.3s
# 83:	learn: 0.1964238	total: 1.03s	remaining: 11.3s
# 84:	learn: 0.1952638	total: 1.04s	remaining: 11.2s
# 85:	learn: 0.1941620	total: 1.05s	remaining: 11.2s
# 86:	learn: 0.1930672	total: 1.07s	remaining: 11.2s
# 87:	learn: 0.1920705	total: 1.08s	remaining: 11.2s
# 88:	learn: 0.1910270	total: 1.09s	remaining: 11.1s
# 89:	learn: 0.1900694	total: 1.1s	remaining: 11.1s
# 90:	learn: 0.1890840	total: 1.11s	remaining: 11.1s
# 91:	learn: 0.1882037	total: 1.12s	remaining: 11.1s
# 92:	learn: 0.1872474	total: 1.13s	remaining: 11s
# 93:	learn: 0.1863517	total: 1.14s	remaining: 11s
# 94:	learn: 0.1854816	total: 1.15s	remaining: 11s
# 95:	learn: 0.1846442	total: 1.16s	remaining: 10.9s
# 96:	learn: 0.1838084	total: 1.17s	remaining: 10.9s
# 97:	learn: 0.1829876	total: 1.18s	remaining: 10.9s
# 98:	learn: 0.1821704	total: 1.19s	remaining: 10.9s
# 99:	learn: 0.1814197	total: 1.21s	remaining: 10.8s
# 100:	learn: 0.1807907	total: 1.22s	remaining: 10.8s
# 101:	learn: 0.1800942	total: 1.23s	remaining: 10.8s
# 102:	learn: 0.1794599	total: 1.24s	remaining: 10.8s
# 103:	learn: 0.1787467	total: 1.25s	remaining: 10.7s
# 104:	learn: 0.1780316	total: 1.26s	remaining: 10.7s
# 105:	learn: 0.1774294	total: 1.27s	remaining: 10.7s
# 106:	learn: 0.1767818	total: 1.28s	remaining: 10.7s
# 107:	learn: 0.1761313	total: 1.29s	remaining: 10.7s
# 108:	learn: 0.1754884	total: 1.3s	remaining: 10.7s
# 109:	learn: 0.1748682	total: 1.31s	remaining: 10.6s
# 110:	learn: 0.1742856	total: 1.32s	remaining: 10.6s
# 111:	learn: 0.1737718	total: 1.34s	remaining: 10.6s
# 112:	learn: 0.1731953	total: 1.35s	remaining: 10.6s
# 113:	learn: 0.1726427	total: 1.36s	remaining: 10.6s
# 114:	learn: 0.1721043	total: 1.37s	remaining: 10.5s
# 115:	learn: 0.1716186	total: 1.38s	remaining: 10.5s
# 116:	learn: 0.1711147	total: 1.39s	remaining: 10.5s
# 117:	learn: 0.1706027	total: 1.4s	remaining: 10.5s
# 118:	learn: 0.1700984	total: 1.41s	remaining: 10.4s
# 119:	learn: 0.1696227	total: 1.42s	remaining: 10.4s
# 120:	learn: 0.1692352	total: 1.43s	remaining: 10.4s
# 121:	learn: 0.1688598	total: 1.44s	remaining: 10.4s
# 122:	learn: 0.1684461	total: 1.45s	remaining: 10.3s
# 123:	learn: 0.1680068	total: 1.46s	remaining: 10.3s
# 124:	learn: 0.1676303	total: 1.47s	remaining: 10.3s
# 125:	learn: 0.1672402	total: 1.48s	remaining: 10.3s
# 126:	learn: 0.1668313	total: 1.49s	remaining: 10.3s
# 127:	learn: 0.1664522	total: 1.5s	remaining: 10.2s
# 128:	learn: 0.1660768	total: 1.51s	remaining: 10.2s
# 129:	learn: 0.1656754	total: 1.52s	remaining: 10.2s
# 130:	learn: 0.1653364	total: 1.53s	remaining: 10.2s
# 131:	learn: 0.1650152	total: 1.54s	remaining: 10.2s
# 132:	learn: 0.1646400	total: 1.55s	remaining: 10.1s
# 133:	learn: 0.1643119	total: 1.56s	remaining: 10.1s
# 134:	learn: 0.1639803	total: 1.58s	remaining: 10.1s
# 135:	learn: 0.1636997	total: 1.59s	remaining: 10.1s
# 136:	learn: 0.1634056	total: 1.6s	remaining: 10.1s
# 137:	learn: 0.1630974	total: 1.61s	remaining: 10s
# 138:	learn: 0.1627761	total: 1.62s	remaining: 10s
# 139:	learn: 0.1624739	total: 1.63s	remaining: 10s
# 140:	learn: 0.1621845	total: 1.64s	remaining: 9.98s
# 141:	learn: 0.1618971	total: 1.65s	remaining: 9.96s
# 142:	learn: 0.1616119	total: 1.66s	remaining: 9.94s
# 143:	learn: 0.1613318	total: 1.67s	remaining: 9.92s
# 144:	learn: 0.1610730	total: 1.68s	remaining: 9.91s
# 145:	learn: 0.1608169	total: 1.69s	remaining: 9.91s
# 146:	learn: 0.1605313	total: 1.71s	remaining: 9.91s
# 147:	learn: 0.1603260	total: 1.72s	remaining: 9.91s
# 148:	learn: 0.1600813	total: 1.74s	remaining: 9.91s
# 149:	learn: 0.1598670	total: 1.75s	remaining: 9.91s
# 150:	learn: 0.1596510	total: 1.76s	remaining: 9.9s
# 151:	learn: 0.1594209	total: 1.77s	remaining: 9.89s
# 152:	learn: 0.1591848	total: 1.78s	remaining: 9.87s
# 153:	learn: 0.1589550	total: 1.79s	remaining: 9.84s
# 154:	learn: 0.1587368	total: 1.8s	remaining: 9.82s
# 155:	learn: 0.1585159	total: 1.81s	remaining: 9.8s
# 156:	learn: 0.1583070	total: 1.82s	remaining: 9.78s
# 157:	learn: 0.1580912	total: 1.83s	remaining: 9.76s
# 158:	learn: 0.1579016	total: 1.84s	remaining: 9.74s
# 159:	learn: 0.1577461	total: 1.85s	remaining: 9.71s
# 160:	learn: 0.1575520	total: 1.86s	remaining: 9.7s
# 161:	learn: 0.1573757	total: 1.87s	remaining: 9.67s
# 162:	learn: 0.1571860	total: 1.88s	remaining: 9.65s
# 163:	learn: 0.1570083	total: 1.89s	remaining: 9.64s
# 164:	learn: 0.1568541	total: 1.9s	remaining: 9.63s
# 165:	learn: 0.1567036	total: 1.91s	remaining: 9.61s
# 166:	learn: 0.1565471	total: 1.92s	remaining: 9.59s
# 167:	learn: 0.1563751	total: 1.93s	remaining: 9.57s
# 168:	learn: 0.1562196	total: 1.94s	remaining: 9.55s
# 169:	learn: 0.1560657	total: 1.95s	remaining: 9.53s
# 170:	learn: 0.1559155	total: 1.96s	remaining: 9.51s
# 171:	learn: 0.1557427	total: 1.97s	remaining: 9.49s
# 172:	learn: 0.1555979	total: 1.98s	remaining: 9.48s
# 173:	learn: 0.1554423	total: 1.99s	remaining: 9.46s
# 174:	learn: 0.1552917	total: 2s	remaining: 9.44s
# 175:	learn: 0.1551502	total: 2.01s	remaining: 9.42s
# 176:	learn: 0.1550033	total: 2.02s	remaining: 9.4s
# 177:	learn: 0.1548666	total: 2.03s	remaining: 9.38s
# 178:	learn: 0.1547367	total: 2.04s	remaining: 9.37s
# 179:	learn: 0.1546211	total: 2.05s	remaining: 9.35s
# 180:	learn: 0.1545026	total: 2.06s	remaining: 9.33s
# 181:	learn: 0.1543654	total: 2.07s	remaining: 9.31s
# 182:	learn: 0.1542465	total: 2.08s	remaining: 9.3s
# 183:	learn: 0.1541227	total: 2.09s	remaining: 9.28s
# 184:	learn: 0.1540064	total: 2.1s	remaining: 9.26s
# 185:	learn: 0.1538998	total: 2.11s	remaining: 9.25s
# 186:	learn: 0.1537983	total: 2.12s	remaining: 9.23s
# 187:	learn: 0.1536872	total: 2.13s	remaining: 9.22s
# 188:	learn: 0.1535874	total: 2.15s	remaining: 9.21s
# 189:	learn: 0.1534729	total: 2.16s	remaining: 9.2s
# 190:	learn: 0.1533651	total: 2.17s	remaining: 9.17s
# 191:	learn: 0.1532745	total: 2.17s	remaining: 9.15s
# 192:	learn: 0.1531805	total: 2.18s	remaining: 9.13s
# 193:	learn: 0.1530979	total: 2.19s	remaining: 9.11s
# 194:	learn: 0.1530073	total: 2.2s	remaining: 9.09s
# 195:	learn: 0.1529104	total: 2.21s	remaining: 9.08s
# 196:	learn: 0.1528287	total: 2.22s	remaining: 9.06s
# 197:	learn: 0.1527298	total: 2.23s	remaining: 9.04s
# 198:	learn: 0.1526365	total: 2.24s	remaining: 9.02s
# 199:	learn: 0.1525540	total: 2.25s	remaining: 9s
# 200:	learn: 0.1524677	total: 2.26s	remaining: 8.98s
# 201:	learn: 0.1523845	total: 2.27s	remaining: 8.96s
# 202:	learn: 0.1522994	total: 2.28s	remaining: 8.95s
# 203:	learn: 0.1522291	total: 2.29s	remaining: 8.93s
# 204:	learn: 0.1521477	total: 2.3s	remaining: 8.91s
# 205:	learn: 0.1520593	total: 2.31s	remaining: 8.89s
# 206:	learn: 0.1519759	total: 2.32s	remaining: 8.88s
# 207:	learn: 0.1519016	total: 2.33s	remaining: 8.85s
# 208:	learn: 0.1518347	total: 2.33s	remaining: 8.83s
# 209:	learn: 0.1517564	total: 2.34s	remaining: 8.81s
# 210:	learn: 0.1516987	total: 2.35s	remaining: 8.79s
# 211:	learn: 0.1516230	total: 2.36s	remaining: 8.78s
# 212:	learn: 0.1515627	total: 2.37s	remaining: 8.76s
# 213:	learn: 0.1515005	total: 2.38s	remaining: 8.73s
# 214:	learn: 0.1514285	total: 2.39s	remaining: 8.71s
# 215:	learn: 0.1513590	total: 2.4s	remaining: 8.7s
# 216:	learn: 0.1513041	total: 2.4s	remaining: 8.67s
# 217:	learn: 0.1512629	total: 2.41s	remaining: 8.65s
# 218:	learn: 0.1511973	total: 2.42s	remaining: 8.63s
# 219:	learn: 0.1511516	total: 2.43s	remaining: 8.62s
# 220:	learn: 0.1510853	total: 2.44s	remaining: 8.6s
# 221:	learn: 0.1510139	total: 2.45s	remaining: 8.58s
# 222:	learn: 0.1509706	total: 2.46s	remaining: 8.56s
# 223:	learn: 0.1509126	total: 2.47s	remaining: 8.54s
# 224:	learn: 0.1508582	total: 2.48s	remaining: 8.53s
# 225:	learn: 0.1508013	total: 2.48s	remaining: 8.51s
# 226:	learn: 0.1507507	total: 2.49s	remaining: 8.49s
# 227:	learn: 0.1506991	total: 2.5s	remaining: 8.47s
# 228:	learn: 0.1506518	total: 2.51s	remaining: 8.46s
# 229:	learn: 0.1505967	total: 2.52s	remaining: 8.45s
# 230:	learn: 0.1505456	total: 2.53s	remaining: 8.44s
# 231:	learn: 0.1504927	total: 2.54s	remaining: 8.42s
# 232:	learn: 0.1504507	total: 2.56s	remaining: 8.41s
# 233:	learn: 0.1503972	total: 2.56s	remaining: 8.4s
# 234:	learn: 0.1503533	total: 2.58s	remaining: 8.39s
# 235:	learn: 0.1503135	total: 2.59s	remaining: 8.37s
# 236:	learn: 0.1502667	total: 2.6s	remaining: 8.36s
# 237:	learn: 0.1502264	total: 2.61s	remaining: 8.35s
# 238:	learn: 0.1501767	total: 2.62s	remaining: 8.34s
# 239:	learn: 0.1501248	total: 2.63s	remaining: 8.32s
# 240:	learn: 0.1500813	total: 2.64s	remaining: 8.3s
# 241:	learn: 0.1500443	total: 2.65s	remaining: 8.29s
# 242:	learn: 0.1500005	total: 2.66s	remaining: 8.28s
# 243:	learn: 0.1499597	total: 2.67s	remaining: 8.26s
# 244:	learn: 0.1499213	total: 2.68s	remaining: 8.25s
# 245:	learn: 0.1498856	total: 2.69s	remaining: 8.23s
# 246:	learn: 0.1498494	total: 2.69s	remaining: 8.22s
# 247:	learn: 0.1498129	total: 2.71s	remaining: 8.2s
# 248:	learn: 0.1497791	total: 2.71s	remaining: 8.19s
# 249:	learn: 0.1497430	total: 2.73s	remaining: 8.18s
# 250:	learn: 0.1497000	total: 2.73s	remaining: 8.16s
# 251:	learn: 0.1496606	total: 2.75s	remaining: 8.15s
# 252:	learn: 0.1496349	total: 2.75s	remaining: 8.13s
# 253:	learn: 0.1495953	total: 2.76s	remaining: 8.12s
# 254:	learn: 0.1495625	total: 2.77s	remaining: 8.1s
# 255:	learn: 0.1495219	total: 2.79s	remaining: 8.09s
# 256:	learn: 0.1494900	total: 2.8s	remaining: 8.08s
# 257:	learn: 0.1494561	total: 2.81s	remaining: 8.07s
# 258:	learn: 0.1494231	total: 2.82s	remaining: 8.06s
# 259:	learn: 0.1493936	total: 2.82s	remaining: 8.04s
# 260:	learn: 0.1493545	total: 2.83s	remaining: 8.02s
# 261:	learn: 0.1493299	total: 2.84s	remaining: 8.01s
# 262:	learn: 0.1493019	total: 2.85s	remaining: 8s
# 263:	learn: 0.1492620	total: 2.86s	remaining: 7.98s
# 264:	learn: 0.1492269	total: 2.87s	remaining: 7.97s
# 265:	learn: 0.1491962	total: 2.88s	remaining: 7.96s
# 266:	learn: 0.1491724	total: 2.89s	remaining: 7.94s
# 267:	learn: 0.1491520	total: 2.9s	remaining: 7.93s
# 268:	learn: 0.1491300	total: 2.91s	remaining: 7.91s
# 269:	learn: 0.1491014	total: 2.92s	remaining: 7.9s
# 270:	learn: 0.1490687	total: 2.93s	remaining: 7.89s
# 271:	learn: 0.1490471	total: 2.94s	remaining: 7.87s
# 272:	learn: 0.1490236	total: 2.95s	remaining: 7.86s
# 273:	learn: 0.1489959	total: 2.96s	remaining: 7.85s
# 274:	learn: 0.1489693	total: 2.97s	remaining: 7.84s
# 275:	learn: 0.1489422	total: 2.98s	remaining: 7.82s
# 276:	learn: 0.1489122	total: 2.99s	remaining: 7.81s
# 277:	learn: 0.1488883	total: 3s	remaining: 7.79s
# 278:	learn: 0.1488579	total: 3.01s	remaining: 7.78s
# 279:	learn: 0.1488379	total: 3.02s	remaining: 7.76s
# 280:	learn: 0.1488066	total: 3.03s	remaining: 7.74s
# 281:	learn: 0.1487785	total: 3.04s	remaining: 7.73s
# 282:	learn: 0.1487592	total: 3.04s	remaining: 7.71s
# 283:	learn: 0.1487399	total: 3.05s	remaining: 7.7s
# 284:	learn: 0.1487114	total: 3.06s	remaining: 7.68s
# 285:	learn: 0.1486878	total: 3.07s	remaining: 7.67s
# 286:	learn: 0.1486664	total: 3.08s	remaining: 7.65s
# 287:	learn: 0.1486429	total: 3.09s	remaining: 7.64s
# 288:	learn: 0.1486115	total: 3.1s	remaining: 7.62s
# 289:	learn: 0.1485883	total: 3.11s	remaining: 7.61s
# 290:	learn: 0.1485682	total: 3.12s	remaining: 7.59s
# 291:	learn: 0.1485516	total: 3.13s	remaining: 7.58s
# 292:	learn: 0.1485311	total: 3.14s	remaining: 7.57s
# 293:	learn: 0.1485113	total: 3.15s	remaining: 7.56s
# 294:	learn: 0.1484903	total: 3.16s	remaining: 7.55s
# 295:	learn: 0.1484712	total: 3.17s	remaining: 7.54s
# 296:	learn: 0.1484480	total: 3.18s	remaining: 7.53s
# 297:	learn: 0.1484267	total: 3.19s	remaining: 7.52s
# 298:	learn: 0.1484063	total: 3.2s	remaining: 7.51s
# 299:	learn: 0.1483842	total: 3.21s	remaining: 7.5s
# 300:	learn: 0.1483658	total: 3.22s	remaining: 7.49s
# 301:	learn: 0.1483504	total: 3.23s	remaining: 7.48s
# 302:	learn: 0.1483302	total: 3.25s	remaining: 7.47s
# 303:	learn: 0.1483131	total: 3.26s	remaining: 7.46s
# 304:	learn: 0.1482876	total: 3.27s	remaining: 7.44s
# 305:	learn: 0.1482673	total: 3.28s	remaining: 7.43s
# 306:	learn: 0.1482514	total: 3.29s	remaining: 7.42s
# 307:	learn: 0.1482302	total: 3.3s	remaining: 7.41s
# 308:	learn: 0.1482141	total: 3.31s	remaining: 7.4s
# 309:	learn: 0.1481959	total: 3.32s	remaining: 7.38s
# 310:	learn: 0.1481756	total: 3.33s	remaining: 7.37s
# 311:	learn: 0.1481539	total: 3.34s	remaining: 7.36s
# 312:	learn: 0.1481337	total: 3.35s	remaining: 7.35s
# 313:	learn: 0.1481164	total: 3.36s	remaining: 7.34s
# 314:	learn: 0.1480947	total: 3.37s	remaining: 7.33s
# 315:	learn: 0.1480739	total: 3.38s	remaining: 7.32s
# 316:	learn: 0.1480565	total: 3.39s	remaining: 7.31s
# 317:	learn: 0.1480413	total: 3.4s	remaining: 7.3s
# 318:	learn: 0.1480261	total: 3.41s	remaining: 7.29s
# 319:	learn: 0.1480154	total: 3.42s	remaining: 7.27s
# 320:	learn: 0.1480034	total: 3.43s	remaining: 7.26s
# 321:	learn: 0.1479848	total: 3.44s	remaining: 7.25s
# 322:	learn: 0.1479694	total: 3.45s	remaining: 7.24s
# 323:	learn: 0.1479514	total: 3.46s	remaining: 7.23s
# 324:	learn: 0.1479304	total: 3.47s	remaining: 7.21s
# 325:	learn: 0.1479152	total: 3.48s	remaining: 7.2s
# 326:	learn: 0.1478962	total: 3.49s	remaining: 7.19s
# 327:	learn: 0.1478818	total: 3.5s	remaining: 7.18s
# 328:	learn: 0.1478686	total: 3.51s	remaining: 7.17s
# 329:	learn: 0.1478455	total: 3.52s	remaining: 7.16s
# 330:	learn: 0.1478292	total: 3.54s	remaining: 7.15s
# 331:	learn: 0.1478128	total: 3.55s	remaining: 7.13s
# 332:	learn: 0.1477974	total: 3.56s	remaining: 7.13s
# 333:	learn: 0.1477843	total: 3.57s	remaining: 7.12s
# 334:	learn: 0.1477698	total: 3.58s	remaining: 7.1s
# 335:	learn: 0.1477527	total: 3.59s	remaining: 7.09s
# 336:	learn: 0.1477356	total: 3.6s	remaining: 7.08s
# 337:	learn: 0.1477241	total: 3.62s	remaining: 7.08s
# 338:	learn: 0.1477108	total: 3.64s	remaining: 7.09s
# 339:	learn: 0.1477014	total: 3.65s	remaining: 7.09s
# 340:	learn: 0.1476889	total: 3.67s	remaining: 7.09s
# 341:	learn: 0.1476791	total: 3.68s	remaining: 7.08s
# 342:	learn: 0.1476638	total: 3.69s	remaining: 7.08s
# 343:	learn: 0.1476530	total: 3.71s	remaining: 7.07s
# 344:	learn: 0.1476447	total: 3.72s	remaining: 7.06s
# 345:	learn: 0.1476305	total: 3.73s	remaining: 7.05s
# 346:	learn: 0.1476144	total: 3.74s	remaining: 7.04s
# 347:	learn: 0.1475995	total: 3.75s	remaining: 7.03s
# 348:	learn: 0.1475892	total: 3.77s	remaining: 7.03s
# 349:	learn: 0.1475785	total: 3.78s	remaining: 7.02s
# 350:	learn: 0.1475649	total: 3.79s	remaining: 7.01s
# 351:	learn: 0.1475523	total: 3.8s	remaining: 7s
# 352:	learn: 0.1475391	total: 3.81s	remaining: 6.99s
# 353:	learn: 0.1475269	total: 3.83s	remaining: 6.98s
# 354:	learn: 0.1475160	total: 3.84s	remaining: 6.97s
# 355:	learn: 0.1475084	total: 3.85s	remaining: 6.96s
# 356:	learn: 0.1474962	total: 3.86s	remaining: 6.95s
# 357:	learn: 0.1474875	total: 3.87s	remaining: 6.94s
# 358:	learn: 0.1474792	total: 3.88s	remaining: 6.93s
# 359:	learn: 0.1474689	total: 3.89s	remaining: 6.91s
# 360:	learn: 0.1474562	total: 3.9s	remaining: 6.9s
# 361:	learn: 0.1474413	total: 3.91s	remaining: 6.89s
# 362:	learn: 0.1474316	total: 3.92s	remaining: 6.88s
# 363:	learn: 0.1474171	total: 3.93s	remaining: 6.87s
# 364:	learn: 0.1474046	total: 3.94s	remaining: 6.86s
# 365:	learn: 0.1473933	total: 3.95s	remaining: 6.85s
# 366:	learn: 0.1473807	total: 3.96s	remaining: 6.84s
# 367:	learn: 0.1473690	total: 3.97s	remaining: 6.82s
# 368:	learn: 0.1473572	total: 3.98s	remaining: 6.81s
# 369:	learn: 0.1473508	total: 3.99s	remaining: 6.8s
# 370:	learn: 0.1473384	total: 4.01s	remaining: 6.79s
# 371:	learn: 0.1473317	total: 4.02s	remaining: 6.78s
# 372:	learn: 0.1473241	total: 4.03s	remaining: 6.77s
# 373:	learn: 0.1473122	total: 4.04s	remaining: 6.76s
# 374:	learn: 0.1473010	total: 4.05s	remaining: 6.75s
# 375:	learn: 0.1472897	total: 4.06s	remaining: 6.73s
# 376:	learn: 0.1472826	total: 4.07s	remaining: 6.72s
# 377:	learn: 0.1472698	total: 4.08s	remaining: 6.71s
# 378:	learn: 0.1472594	total: 4.08s	remaining: 6.69s
# 379:	learn: 0.1472511	total: 4.09s	remaining: 6.68s
# 380:	learn: 0.1472376	total: 4.1s	remaining: 6.67s
# 381:	learn: 0.1472254	total: 4.11s	remaining: 6.65s
# 382:	learn: 0.1472184	total: 4.12s	remaining: 6.64s
# 383:	learn: 0.1472047	total: 4.13s	remaining: 6.63s
# 384:	learn: 0.1471956	total: 4.14s	remaining: 6.61s
# 385:	learn: 0.1471852	total: 4.15s	remaining: 6.6s
# 386:	learn: 0.1471750	total: 4.16s	remaining: 6.59s
# 387:	learn: 0.1471637	total: 4.17s	remaining: 6.58s
# 388:	learn: 0.1471559	total: 4.18s	remaining: 6.57s
# 389:	learn: 0.1471479	total: 4.19s	remaining: 6.55s
# 390:	learn: 0.1471392	total: 4.2s	remaining: 6.54s
# 391:	learn: 0.1471331	total: 4.21s	remaining: 6.53s
# 392:	learn: 0.1471259	total: 4.22s	remaining: 6.52s
# 393:	learn: 0.1471188	total: 4.23s	remaining: 6.51s
# 394:	learn: 0.1471083	total: 4.24s	remaining: 6.5s
# 395:	learn: 0.1470964	total: 4.25s	remaining: 6.49s
# 396:	learn: 0.1470855	total: 4.26s	remaining: 6.47s
# 397:	learn: 0.1470750	total: 4.27s	remaining: 6.46s
# 398:	learn: 0.1470676	total: 4.28s	remaining: 6.45s
# 399:	learn: 0.1470611	total: 4.29s	remaining: 6.43s
# 400:	learn: 0.1470517	total: 4.3s	remaining: 6.42s
# 401:	learn: 0.1470423	total: 4.31s	remaining: 6.41s
# 402:	learn: 0.1470336	total: 4.32s	remaining: 6.4s
# 403:	learn: 0.1470223	total: 4.33s	remaining: 6.38s
# 404:	learn: 0.1470158	total: 4.34s	remaining: 6.37s
# 405:	learn: 0.1470095	total: 4.35s	remaining: 6.36s
# 406:	learn: 0.1469984	total: 4.36s	remaining: 6.35s
# 407:	learn: 0.1469876	total: 4.37s	remaining: 6.34s
# 408:	learn: 0.1469767	total: 4.38s	remaining: 6.33s
# 409:	learn: 0.1469670	total: 4.39s	remaining: 6.32s
# 410:	learn: 0.1469586	total: 4.4s	remaining: 6.31s
# 411:	learn: 0.1469479	total: 4.41s	remaining: 6.3s
# 412:	learn: 0.1469421	total: 4.42s	remaining: 6.29s
# 413:	learn: 0.1469311	total: 4.43s	remaining: 6.28s
# 414:	learn: 0.1469195	total: 4.45s	remaining: 6.27s
# 415:	learn: 0.1469120	total: 4.46s	remaining: 6.26s
# 416:	learn: 0.1469053	total: 4.47s	remaining: 6.25s
# 417:	learn: 0.1468986	total: 4.48s	remaining: 6.24s
# 418:	learn: 0.1468938	total: 4.5s	remaining: 6.23s
# 419:	learn: 0.1468856	total: 4.51s	remaining: 6.23s
# 420:	learn: 0.1468780	total: 4.52s	remaining: 6.22s
# 421:	learn: 0.1468708	total: 4.53s	remaining: 6.21s
# 422:	learn: 0.1468634	total: 4.54s	remaining: 6.2s
# 423:	learn: 0.1468559	total: 4.55s	remaining: 6.19s
# 424:	learn: 0.1468474	total: 4.57s	remaining: 6.18s
# 425:	learn: 0.1468385	total: 4.58s	remaining: 6.17s
# 426:	learn: 0.1468296	total: 4.59s	remaining: 6.15s
# 427:	learn: 0.1468236	total: 4.6s	remaining: 6.14s
# 428:	learn: 0.1468172	total: 4.61s	remaining: 6.13s
# 429:	learn: 0.1468116	total: 4.62s	remaining: 6.12s
# 430:	learn: 0.1467992	total: 4.63s	remaining: 6.11s
# 431:	learn: 0.1467937	total: 4.64s	remaining: 6.1s
# 432:	learn: 0.1467876	total: 4.65s	remaining: 6.09s
# 433:	learn: 0.1467775	total: 4.66s	remaining: 6.08s
# 434:	learn: 0.1467712	total: 4.67s	remaining: 6.07s
# 435:	learn: 0.1467663	total: 4.69s	remaining: 6.07s
# 436:	learn: 0.1467556	total: 4.71s	remaining: 6.06s
# 437:	learn: 0.1467486	total: 4.72s	remaining: 6.05s
# 438:	learn: 0.1467396	total: 4.73s	remaining: 6.04s
# 439:	learn: 0.1467345	total: 4.74s	remaining: 6.04s
# 440:	learn: 0.1467288	total: 4.75s	remaining: 6.02s
# 441:	learn: 0.1467235	total: 4.76s	remaining: 6.01s
# 442:	learn: 0.1467166	total: 4.77s	remaining: 6s
# 443:	learn: 0.1467070	total: 4.78s	remaining: 5.99s
# 444:	learn: 0.1466991	total: 4.79s	remaining: 5.98s
# 445:	learn: 0.1466930	total: 4.8s	remaining: 5.96s
# 446:	learn: 0.1466840	total: 4.81s	remaining: 5.95s
# 447:	learn: 0.1466775	total: 4.82s	remaining: 5.94s
# 448:	learn: 0.1466681	total: 4.84s	remaining: 5.93s
# 449:	learn: 0.1466603	total: 4.85s	remaining: 5.92s
# 450:	learn: 0.1466561	total: 4.86s	remaining: 5.91s
# 451:	learn: 0.1466511	total: 4.87s	remaining: 5.9s
# 452:	learn: 0.1466434	total: 4.88s	remaining: 5.89s
# 453:	learn: 0.1466352	total: 4.89s	remaining: 5.88s
# 454:	learn: 0.1466297	total: 4.9s	remaining: 5.87s
# 455:	learn: 0.1466256	total: 4.91s	remaining: 5.86s
# 456:	learn: 0.1466171	total: 4.92s	remaining: 5.84s
# 457:	learn: 0.1466091	total: 4.93s	remaining: 5.83s
# 458:	learn: 0.1466034	total: 4.94s	remaining: 5.82s
# 459:	learn: 0.1465951	total: 4.95s	remaining: 5.81s
# 460:	learn: 0.1465885	total: 4.96s	remaining: 5.79s
# 461:	learn: 0.1465851	total: 4.96s	remaining: 5.78s
# 462:	learn: 0.1465769	total: 4.97s	remaining: 5.77s
# 463:	learn: 0.1465705	total: 4.98s	remaining: 5.76s
# 464:	learn: 0.1465651	total: 4.99s	remaining: 5.75s
# 465:	learn: 0.1465603	total: 5s	remaining: 5.73s
# 466:	learn: 0.1465537	total: 5.01s	remaining: 5.72s
# 467:	learn: 0.1465434	total: 5.02s	remaining: 5.71s
# 468:	learn: 0.1465356	total: 5.03s	remaining: 5.7s
# 469:	learn: 0.1465291	total: 5.04s	remaining: 5.69s
# 470:	learn: 0.1465239	total: 5.05s	remaining: 5.67s
# 471:	learn: 0.1465198	total: 5.06s	remaining: 5.66s
# 472:	learn: 0.1465116	total: 5.07s	remaining: 5.65s
# 473:	learn: 0.1465068	total: 5.08s	remaining: 5.64s
# 474:	learn: 0.1465000	total: 5.09s	remaining: 5.63s
# 475:	learn: 0.1464942	total: 5.1s	remaining: 5.62s
# 476:	learn: 0.1464867	total: 5.11s	remaining: 5.61s
# 477:	learn: 0.1464816	total: 5.12s	remaining: 5.6s
# 478:	learn: 0.1464748	total: 5.13s	remaining: 5.58s
# 479:	learn: 0.1464700	total: 5.14s	remaining: 5.57s
# 480:	learn: 0.1464612	total: 5.15s	remaining: 5.56s
# 481:	learn: 0.1464547	total: 5.16s	remaining: 5.55s
# 482:	learn: 0.1464504	total: 5.17s	remaining: 5.54s
# 483:	learn: 0.1464422	total: 5.18s	remaining: 5.53s
# 484:	learn: 0.1464373	total: 5.19s	remaining: 5.51s
# 485:	learn: 0.1464307	total: 5.2s	remaining: 5.5s
# 486:	learn: 0.1464250	total: 5.21s	remaining: 5.49s
# 487:	learn: 0.1464185	total: 5.22s	remaining: 5.48s
# 488:	learn: 0.1464110	total: 5.23s	remaining: 5.47s
# 489:	learn: 0.1464056	total: 5.24s	remaining: 5.46s
# 490:	learn: 0.1464013	total: 5.25s	remaining: 5.44s
# 491:	learn: 0.1463978	total: 5.26s	remaining: 5.43s
# 492:	learn: 0.1463894	total: 5.27s	remaining: 5.42s
# 493:	learn: 0.1463816	total: 5.28s	remaining: 5.41s
# 494:	learn: 0.1463753	total: 5.29s	remaining: 5.4s
# 495:	learn: 0.1463690	total: 5.3s	remaining: 5.39s
# 496:	learn: 0.1463630	total: 5.32s	remaining: 5.38s
# 497:	learn: 0.1463589	total: 5.33s	remaining: 5.37s
# 498:	learn: 0.1463506	total: 5.34s	remaining: 5.36s
# 499:	learn: 0.1463448	total: 5.35s	remaining: 5.35s
# 500:	learn: 0.1463383	total: 5.36s	remaining: 5.34s
# 501:	learn: 0.1463342	total: 5.37s	remaining: 5.33s
# 502:	learn: 0.1463279	total: 5.38s	remaining: 5.32s
# 503:	learn: 0.1463219	total: 5.39s	remaining: 5.31s
# 504:	learn: 0.1463184	total: 5.4s	remaining: 5.3s
# 505:	learn: 0.1463122	total: 5.41s	remaining: 5.29s
# 506:	learn: 0.1463071	total: 5.42s	remaining: 5.27s
# 507:	learn: 0.1463026	total: 5.43s	remaining: 5.26s
# 508:	learn: 0.1462980	total: 5.44s	remaining: 5.25s
# 509:	learn: 0.1462931	total: 5.45s	remaining: 5.24s
# 510:	learn: 0.1462864	total: 5.47s	remaining: 5.23s
# 511:	learn: 0.1462840	total: 5.48s	remaining: 5.22s
# 512:	learn: 0.1462784	total: 5.49s	remaining: 5.21s
# 513:	learn: 0.1462734	total: 5.5s	remaining: 5.2s
# 514:	learn: 0.1462682	total: 5.52s	remaining: 5.19s
# 515:	learn: 0.1462632	total: 5.53s	remaining: 5.19s
# 516:	learn: 0.1462595	total: 5.54s	remaining: 5.18s
# 517:	learn: 0.1462568	total: 5.56s	remaining: 5.17s
# 518:	learn: 0.1462509	total: 5.57s	remaining: 5.16s
# 519:	learn: 0.1462443	total: 5.58s	remaining: 5.16s
# 520:	learn: 0.1462393	total: 5.6s	remaining: 5.14s
# 521:	learn: 0.1462291	total: 5.61s	remaining: 5.13s
# 522:	learn: 0.1462235	total: 5.62s	remaining: 5.12s
# 523:	learn: 0.1462189	total: 5.63s	remaining: 5.11s
# 524:	learn: 0.1462127	total: 5.64s	remaining: 5.1s
# 525:	learn: 0.1462063	total: 5.65s	remaining: 5.09s
# 526:	learn: 0.1462009	total: 5.66s	remaining: 5.08s
# 527:	learn: 0.1461977	total: 5.67s	remaining: 5.07s
# 528:	learn: 0.1461928	total: 5.68s	remaining: 5.06s
# 529:	learn: 0.1461869	total: 5.69s	remaining: 5.05s
# 530:	learn: 0.1461821	total: 5.7s	remaining: 5.04s
# 531:	learn: 0.1461786	total: 5.71s	remaining: 5.03s
# 532:	learn: 0.1461738	total: 5.72s	remaining: 5.02s
# 533:	learn: 0.1461703	total: 5.74s	remaining: 5s
# 534:	learn: 0.1461658	total: 5.75s	remaining: 4.99s
# 535:	learn: 0.1461605	total: 5.76s	remaining: 4.98s
# 536:	learn: 0.1461542	total: 5.77s	remaining: 4.97s
# 537:	learn: 0.1461483	total: 5.78s	remaining: 4.96s
# 538:	learn: 0.1461447	total: 5.79s	remaining: 4.95s
# 539:	learn: 0.1461402	total: 5.8s	remaining: 4.94s
# 540:	learn: 0.1461347	total: 5.81s	remaining: 4.93s
# 541:	learn: 0.1461296	total: 5.82s	remaining: 4.92s
# 542:	learn: 0.1461259	total: 5.83s	remaining: 4.91s
# 543:	learn: 0.1461201	total: 5.84s	remaining: 4.9s
# 544:	learn: 0.1461126	total: 5.85s	remaining: 4.89s
# 545:	learn: 0.1461073	total: 5.86s	remaining: 4.88s
# 546:	learn: 0.1461032	total: 5.88s	remaining: 4.87s
# 547:	learn: 0.1461003	total: 5.88s	remaining: 4.85s
# 548:	learn: 0.1460968	total: 5.9s	remaining: 4.84s
# 549:	learn: 0.1460934	total: 5.91s	remaining: 4.83s
# 550:	learn: 0.1460875	total: 5.92s	remaining: 4.82s
# 551:	learn: 0.1460839	total: 5.93s	remaining: 4.81s
# 552:	learn: 0.1460770	total: 5.93s	remaining: 4.8s
# 553:	learn: 0.1460733	total: 5.94s	remaining: 4.79s
# 554:	learn: 0.1460710	total: 5.95s	remaining: 4.77s
# 555:	learn: 0.1460640	total: 5.96s	remaining: 4.76s
# 556:	learn: 0.1460576	total: 5.97s	remaining: 4.75s
# 557:	learn: 0.1460526	total: 5.98s	remaining: 4.74s
# 558:	learn: 0.1460489	total: 5.99s	remaining: 4.72s
# 559:	learn: 0.1460438	total: 6s	remaining: 4.71s
# 560:	learn: 0.1460402	total: 6.01s	remaining: 4.7s
# 561:	learn: 0.1460357	total: 6.02s	remaining: 4.69s
# 562:	learn: 0.1460301	total: 6.03s	remaining: 4.68s
# 563:	learn: 0.1460248	total: 6.04s	remaining: 4.67s
# 564:	learn: 0.1460207	total: 6.05s	remaining: 4.66s
# 565:	learn: 0.1460148	total: 6.06s	remaining: 4.64s
# 566:	learn: 0.1460040	total: 6.07s	remaining: 4.63s
# 567:	learn: 0.1459994	total: 6.08s	remaining: 4.62s
# 568:	learn: 0.1459947	total: 6.09s	remaining: 4.61s
# 569:	learn: 0.1459887	total: 6.09s	remaining: 4.6s
# 570:	learn: 0.1459847	total: 6.1s	remaining: 4.59s
# 571:	learn: 0.1459813	total: 6.12s	remaining: 4.58s
# 572:	learn: 0.1459768	total: 6.13s	remaining: 4.57s
# 573:	learn: 0.1459727	total: 6.14s	remaining: 4.56s
# 574:	learn: 0.1459684	total: 6.15s	remaining: 4.54s
# 575:	learn: 0.1459618	total: 6.16s	remaining: 4.53s
# 576:	learn: 0.1459563	total: 6.17s	remaining: 4.52s
# 577:	learn: 0.1459504	total: 6.18s	remaining: 4.51s
# 578:	learn: 0.1459458	total: 6.2s	remaining: 4.5s
# 579:	learn: 0.1459407	total: 6.21s	remaining: 4.5s
# 580:	learn: 0.1459379	total: 6.22s	remaining: 4.49s
# 581:	learn: 0.1459343	total: 6.23s	remaining: 4.47s
# 582:	learn: 0.1459292	total: 6.24s	remaining: 4.46s
# 583:	learn: 0.1459249	total: 6.25s	remaining: 4.45s
# 584:	learn: 0.1459205	total: 6.26s	remaining: 4.44s
# 585:	learn: 0.1459167	total: 6.27s	remaining: 4.43s
# 586:	learn: 0.1459132	total: 6.28s	remaining: 4.42s
# 587:	learn: 0.1459071	total: 6.29s	remaining: 4.41s
# 588:	learn: 0.1459004	total: 6.3s	remaining: 4.4s
# 589:	learn: 0.1458927	total: 6.31s	remaining: 4.39s
# 590:	learn: 0.1458883	total: 6.33s	remaining: 4.38s
# 591:	learn: 0.1458833	total: 6.33s	remaining: 4.37s
# 592:	learn: 0.1458799	total: 6.35s	remaining: 4.36s
# 593:	learn: 0.1458742	total: 6.36s	remaining: 4.35s
# 594:	learn: 0.1458658	total: 6.37s	remaining: 4.34s
# 595:	learn: 0.1458615	total: 6.39s	remaining: 4.33s
# 596:	learn: 0.1458570	total: 6.4s	remaining: 4.32s
# 597:	learn: 0.1458511	total: 6.41s	remaining: 4.31s
# 598:	learn: 0.1458476	total: 6.42s	remaining: 4.3s
# 599:	learn: 0.1458440	total: 6.43s	remaining: 4.29s
# 600:	learn: 0.1458379	total: 6.44s	remaining: 4.27s
# 601:	learn: 0.1458328	total: 6.45s	remaining: 4.26s
# 602:	learn: 0.1458267	total: 6.46s	remaining: 4.25s
# 603:	learn: 0.1458209	total: 6.47s	remaining: 4.24s
# 604:	learn: 0.1458137	total: 6.48s	remaining: 4.23s
# 605:	learn: 0.1458107	total: 6.49s	remaining: 4.22s
# 606:	learn: 0.1458054	total: 6.5s	remaining: 4.21s
# 607:	learn: 0.1457989	total: 6.5s	remaining: 4.19s
# 608:	learn: 0.1457927	total: 6.51s	remaining: 4.18s
# 609:	learn: 0.1457905	total: 6.52s	remaining: 4.17s
# 610:	learn: 0.1457830	total: 6.53s	remaining: 4.16s
# 611:	learn: 0.1457772	total: 6.54s	remaining: 4.15s
# 612:	learn: 0.1457719	total: 6.55s	remaining: 4.14s
# 613:	learn: 0.1457663	total: 6.57s	remaining: 4.13s
# 614:	learn: 0.1457584	total: 6.58s	remaining: 4.12s
# 615:	learn: 0.1457549	total: 6.59s	remaining: 4.11s
# 616:	learn: 0.1457488	total: 6.6s	remaining: 4.09s
# 617:	learn: 0.1457447	total: 6.61s	remaining: 4.08s
# 618:	learn: 0.1457404	total: 6.62s	remaining: 4.07s
# 619:	learn: 0.1457362	total: 6.63s	remaining: 4.06s
# 620:	learn: 0.1457311	total: 6.63s	remaining: 4.05s
# 621:	learn: 0.1457266	total: 6.64s	remaining: 4.04s
# 622:	learn: 0.1457215	total: 6.65s	remaining: 4.03s
# 623:	learn: 0.1457163	total: 6.66s	remaining: 4.01s
# 624:	learn: 0.1457140	total: 6.67s	remaining: 4s
# 625:	learn: 0.1457091	total: 6.68s	remaining: 3.99s
# 626:	learn: 0.1457049	total: 6.69s	remaining: 3.98s
# 627:	learn: 0.1457006	total: 6.7s	remaining: 3.97s
# 628:	learn: 0.1456938	total: 6.71s	remaining: 3.96s
# 629:	learn: 0.1456883	total: 6.72s	remaining: 3.95s
# 630:	learn: 0.1456827	total: 6.73s	remaining: 3.94s
# 631:	learn: 0.1456786	total: 6.75s	remaining: 3.93s
# 632:	learn: 0.1456742	total: 6.76s	remaining: 3.92s
# 633:	learn: 0.1456691	total: 6.77s	remaining: 3.91s
# 634:	learn: 0.1456660	total: 6.78s	remaining: 3.9s
# 635:	learn: 0.1456609	total: 6.79s	remaining: 3.89s
# 636:	learn: 0.1456569	total: 6.8s	remaining: 3.88s
# 637:	learn: 0.1456522	total: 6.81s	remaining: 3.87s
# 638:	learn: 0.1456504	total: 6.82s	remaining: 3.85s
# 639:	learn: 0.1456461	total: 6.83s	remaining: 3.84s
# 640:	learn: 0.1456413	total: 6.84s	remaining: 3.83s
# 641:	learn: 0.1456363	total: 6.85s	remaining: 3.82s
# 642:	learn: 0.1456334	total: 6.87s	remaining: 3.81s
# 643:	learn: 0.1456281	total: 6.88s	remaining: 3.8s
# 644:	learn: 0.1456254	total: 6.89s	remaining: 3.79s
# 645:	learn: 0.1456189	total: 6.9s	remaining: 3.78s
# 646:	learn: 0.1456149	total: 6.91s	remaining: 3.77s
# 647:	learn: 0.1456121	total: 6.92s	remaining: 3.76s
# 648:	learn: 0.1456080	total: 6.93s	remaining: 3.75s
# 649:	learn: 0.1456057	total: 6.94s	remaining: 3.74s
# 650:	learn: 0.1456007	total: 6.96s	remaining: 3.73s
# 651:	learn: 0.1455988	total: 6.97s	remaining: 3.72s
# 652:	learn: 0.1455963	total: 6.98s	remaining: 3.71s
# 653:	learn: 0.1455906	total: 6.99s	remaining: 3.7s
# 654:	learn: 0.1455877	total: 7s	remaining: 3.69s
# 655:	learn: 0.1455810	total: 7.01s	remaining: 3.68s
# 656:	learn: 0.1455776	total: 7.02s	remaining: 3.67s
# 657:	learn: 0.1455741	total: 7.03s	remaining: 3.65s
# 658:	learn: 0.1455693	total: 7.04s	remaining: 3.64s
# 659:	learn: 0.1455662	total: 7.05s	remaining: 3.63s
# 660:	learn: 0.1455611	total: 7.06s	remaining: 3.62s
# 661:	learn: 0.1455569	total: 7.07s	remaining: 3.61s
# 662:	learn: 0.1455536	total: 7.08s	remaining: 3.6s
# 663:	learn: 0.1455498	total: 7.09s	remaining: 3.59s
# 664:	learn: 0.1455464	total: 7.1s	remaining: 3.58s
# 665:	learn: 0.1455419	total: 7.12s	remaining: 3.57s
# 666:	learn: 0.1455386	total: 7.13s	remaining: 3.56s
# 667:	learn: 0.1455307	total: 7.13s	remaining: 3.55s
# 668:	learn: 0.1455254	total: 7.14s	remaining: 3.54s
# 669:	learn: 0.1455216	total: 7.16s	remaining: 3.52s
# 670:	learn: 0.1455191	total: 7.17s	remaining: 3.51s
# 671:	learn: 0.1455157	total: 7.18s	remaining: 3.5s
# 672:	learn: 0.1455125	total: 7.19s	remaining: 3.49s
# 673:	learn: 0.1455075	total: 7.21s	remaining: 3.48s
# 674:	learn: 0.1455001	total: 7.22s	remaining: 3.48s
# 675:	learn: 0.1454960	total: 7.24s	remaining: 3.47s
# 676:	learn: 0.1454891	total: 7.25s	remaining: 3.46s
# 677:	learn: 0.1454851	total: 7.26s	remaining: 3.45s
# 678:	learn: 0.1454806	total: 7.27s	remaining: 3.44s
# 679:	learn: 0.1454738	total: 7.28s	remaining: 3.43s
# 680:	learn: 0.1454699	total: 7.29s	remaining: 3.42s
# 681:	learn: 0.1454658	total: 7.3s	remaining: 3.4s
# 682:	learn: 0.1454617	total: 7.31s	remaining: 3.39s
# 683:	learn: 0.1454565	total: 7.32s	remaining: 3.38s
# 684:	learn: 0.1454525	total: 7.33s	remaining: 3.37s
# 685:	learn: 0.1454485	total: 7.34s	remaining: 3.36s
# 686:	learn: 0.1454460	total: 7.35s	remaining: 3.35s
# 687:	learn: 0.1454402	total: 7.37s	remaining: 3.34s
# 688:	learn: 0.1454363	total: 7.38s	remaining: 3.33s
# 689:	learn: 0.1454304	total: 7.39s	remaining: 3.32s
# 690:	learn: 0.1454271	total: 7.4s	remaining: 3.31s
# 691:	learn: 0.1454243	total: 7.41s	remaining: 3.3s
# 692:	learn: 0.1454199	total: 7.42s	remaining: 3.29s
# 693:	learn: 0.1454147	total: 7.44s	remaining: 3.28s
# 694:	learn: 0.1454087	total: 7.45s	remaining: 3.27s
# 695:	learn: 0.1454055	total: 7.46s	remaining: 3.26s
# 696:	learn: 0.1454018	total: 7.47s	remaining: 3.25s
# 697:	learn: 0.1453990	total: 7.49s	remaining: 3.24s
# 698:	learn: 0.1453968	total: 7.5s	remaining: 3.23s
# 699:	learn: 0.1453919	total: 7.51s	remaining: 3.22s
# 700:	learn: 0.1453892	total: 7.52s	remaining: 3.21s
# 701:	learn: 0.1453865	total: 7.54s	remaining: 3.2s
# 702:	learn: 0.1453831	total: 7.55s	remaining: 3.19s
# 703:	learn: 0.1453784	total: 7.56s	remaining: 3.18s
# 704:	learn: 0.1453724	total: 7.57s	remaining: 3.17s
# 705:	learn: 0.1453685	total: 7.59s	remaining: 3.16s
# 706:	learn: 0.1453653	total: 7.6s	remaining: 3.15s
# 707:	learn: 0.1453632	total: 7.61s	remaining: 3.14s
# 708:	learn: 0.1453582	total: 7.63s	remaining: 3.13s
# 709:	learn: 0.1453534	total: 7.64s	remaining: 3.12s
# 710:	learn: 0.1453481	total: 7.65s	remaining: 3.11s
# 711:	learn: 0.1453453	total: 7.66s	remaining: 3.1s
# 712:	learn: 0.1453406	total: 7.67s	remaining: 3.09s
# 713:	learn: 0.1453378	total: 7.68s	remaining: 3.08s
# 714:	learn: 0.1453351	total: 7.69s	remaining: 3.06s
# 715:	learn: 0.1453328	total: 7.7s	remaining: 3.05s
# 716:	learn: 0.1453301	total: 7.71s	remaining: 3.04s
# 717:	learn: 0.1453255	total: 7.72s	remaining: 3.03s
# 718:	learn: 0.1453216	total: 7.73s	remaining: 3.02s
# 719:	learn: 0.1453152	total: 7.74s	remaining: 3.01s
# 720:	learn: 0.1453128	total: 7.75s	remaining: 3s
# 721:	learn: 0.1453079	total: 7.76s	remaining: 2.99s
# 722:	learn: 0.1453025	total: 7.77s	remaining: 2.98s
# 723:	learn: 0.1452968	total: 7.78s	remaining: 2.97s
# 724:	learn: 0.1452942	total: 7.79s	remaining: 2.96s
# 725:	learn: 0.1452895	total: 7.8s	remaining: 2.94s
# 726:	learn: 0.1452849	total: 7.82s	remaining: 2.93s
# 727:	learn: 0.1452814	total: 7.83s	remaining: 2.92s
# 728:	learn: 0.1452787	total: 7.84s	remaining: 2.92s
# 729:	learn: 0.1452753	total: 7.86s	remaining: 2.91s
# 730:	learn: 0.1452700	total: 7.88s	remaining: 2.9s
# 731:	learn: 0.1452663	total: 7.89s	remaining: 2.89s
# 732:	learn: 0.1452613	total: 7.9s	remaining: 2.88s
# 733:	learn: 0.1452592	total: 7.91s	remaining: 2.87s
# 734:	learn: 0.1452558	total: 7.92s	remaining: 2.86s
# 735:	learn: 0.1452497	total: 7.93s	remaining: 2.85s
# 736:	learn: 0.1452468	total: 7.95s	remaining: 2.83s
# 737:	learn: 0.1452414	total: 7.96s	remaining: 2.82s
# 738:	learn: 0.1452395	total: 7.97s	remaining: 2.81s
# 739:	learn: 0.1452359	total: 7.98s	remaining: 2.8s
# 740:	learn: 0.1452311	total: 7.99s	remaining: 2.79s
# 741:	learn: 0.1452266	total: 8.01s	remaining: 2.78s
# 742:	learn: 0.1452223	total: 8.02s	remaining: 2.77s
# 743:	learn: 0.1452193	total: 8.03s	remaining: 2.76s
# 744:	learn: 0.1452168	total: 8.04s	remaining: 2.75s
# 745:	learn: 0.1452108	total: 8.05s	remaining: 2.74s
# 746:	learn: 0.1452078	total: 8.06s	remaining: 2.73s
# 747:	learn: 0.1452038	total: 8.07s	remaining: 2.72s
# 748:	learn: 0.1452018	total: 8.08s	remaining: 2.71s
# 749:	learn: 0.1451992	total: 8.1s	remaining: 2.7s
# 750:	learn: 0.1451941	total: 8.11s	remaining: 2.69s
# 751:	learn: 0.1451858	total: 8.12s	remaining: 2.68s
# 752:	learn: 0.1451815	total: 8.13s	remaining: 2.67s
# 753:	learn: 0.1451775	total: 8.14s	remaining: 2.65s
# 754:	learn: 0.1451746	total: 8.15s	remaining: 2.65s
# 755:	learn: 0.1451712	total: 8.16s	remaining: 2.63s
# 756:	learn: 0.1451672	total: 8.17s	remaining: 2.62s
# 757:	learn: 0.1451624	total: 8.18s	remaining: 2.61s
# 758:	learn: 0.1451575	total: 8.2s	remaining: 2.6s
# 759:	learn: 0.1451559	total: 8.21s	remaining: 2.59s
# 760:	learn: 0.1451532	total: 8.21s	remaining: 2.58s
# 761:	learn: 0.1451494	total: 8.23s	remaining: 2.57s
# 762:	learn: 0.1451453	total: 8.24s	remaining: 2.56s
# 763:	learn: 0.1451420	total: 8.25s	remaining: 2.55s
# 764:	learn: 0.1451392	total: 8.26s	remaining: 2.54s
# 765:	learn: 0.1451341	total: 8.27s	remaining: 2.53s
# 766:	learn: 0.1451317	total: 8.28s	remaining: 2.52s
# 767:	learn: 0.1451249	total: 8.29s	remaining: 2.5s
# 768:	learn: 0.1451195	total: 8.3s	remaining: 2.49s
# 769:	learn: 0.1451156	total: 8.31s	remaining: 2.48s
# 770:	learn: 0.1451126	total: 8.32s	remaining: 2.47s
# 771:	learn: 0.1451070	total: 8.33s	remaining: 2.46s
# 772:	learn: 0.1451017	total: 8.34s	remaining: 2.45s
# 773:	learn: 0.1450977	total: 8.35s	remaining: 2.44s
# 774:	learn: 0.1450928	total: 8.36s	remaining: 2.43s
# 775:	learn: 0.1450894	total: 8.37s	remaining: 2.42s
# 776:	learn: 0.1450864	total: 8.38s	remaining: 2.4s
# 777:	learn: 0.1450802	total: 8.39s	remaining: 2.39s
# 778:	learn: 0.1450756	total: 8.4s	remaining: 2.38s
# 779:	learn: 0.1450736	total: 8.41s	remaining: 2.37s
# 780:	learn: 0.1450668	total: 8.42s	remaining: 2.36s
# 781:	learn: 0.1450643	total: 8.43s	remaining: 2.35s
# 782:	learn: 0.1450570	total: 8.44s	remaining: 2.34s
# 783:	learn: 0.1450523	total: 8.45s	remaining: 2.33s
# 784:	learn: 0.1450480	total: 8.46s	remaining: 2.32s
# 785:	learn: 0.1450446	total: 8.48s	remaining: 2.31s
# 786:	learn: 0.1450425	total: 8.49s	remaining: 2.3s
# 787:	learn: 0.1450381	total: 8.51s	remaining: 2.29s
# 788:	learn: 0.1450349	total: 8.52s	remaining: 2.28s
# 789:	learn: 0.1450313	total: 8.53s	remaining: 2.27s
# 790:	learn: 0.1450282	total: 8.54s	remaining: 2.26s
# 791:	learn: 0.1450243	total: 8.55s	remaining: 2.25s
# 792:	learn: 0.1450192	total: 8.56s	remaining: 2.23s
# 793:	learn: 0.1450155	total: 8.57s	remaining: 2.22s
# 794:	learn: 0.1450124	total: 8.59s	remaining: 2.21s
# 795:	learn: 0.1450096	total: 8.6s	remaining: 2.2s
# 796:	learn: 0.1450043	total: 8.61s	remaining: 2.19s
# 797:	learn: 0.1449998	total: 8.62s	remaining: 2.18s
# 798:	learn: 0.1449967	total: 8.63s	remaining: 2.17s
# 799:	learn: 0.1449952	total: 8.64s	remaining: 2.16s
# 800:	learn: 0.1449886	total: 8.65s	remaining: 2.15s
# 801:	learn: 0.1449841	total: 8.66s	remaining: 2.14s
# 802:	learn: 0.1449793	total: 8.67s	remaining: 2.13s
# 803:	learn: 0.1449755	total: 8.68s	remaining: 2.12s
# 804:	learn: 0.1449730	total: 8.69s	remaining: 2.1s
# 805:	learn: 0.1449690	total: 8.7s	remaining: 2.09s
# 806:	learn: 0.1449656	total: 8.71s	remaining: 2.08s
# 807:	learn: 0.1449619	total: 8.72s	remaining: 2.07s
# 808:	learn: 0.1449588	total: 8.73s	remaining: 2.06s
# 809:	learn: 0.1449549	total: 8.74s	remaining: 2.05s
# 810:	learn: 0.1449521	total: 8.75s	remaining: 2.04s
# 811:	learn: 0.1449489	total: 8.76s	remaining: 2.03s
# 812:	learn: 0.1449455	total: 8.77s	remaining: 2.02s
# 813:	learn: 0.1449426	total: 8.78s	remaining: 2.01s
# 814:	learn: 0.1449383	total: 8.79s	remaining: 2s
# 815:	learn: 0.1449373	total: 8.8s	remaining: 1.99s
# 816:	learn: 0.1449318	total: 8.81s	remaining: 1.97s
# 817:	learn: 0.1449287	total: 8.82s	remaining: 1.96s
# 818:	learn: 0.1449241	total: 8.83s	remaining: 1.95s
# 819:	learn: 0.1449212	total: 8.84s	remaining: 1.94s
# 820:	learn: 0.1449156	total: 8.85s	remaining: 1.93s
# 821:	learn: 0.1449110	total: 8.87s	remaining: 1.92s
# 822:	learn: 0.1449084	total: 8.88s	remaining: 1.91s
# 823:	learn: 0.1449030	total: 8.89s	remaining: 1.9s
# 824:	learn: 0.1448978	total: 8.9s	remaining: 1.89s
# 825:	learn: 0.1448950	total: 8.91s	remaining: 1.88s
# 826:	learn: 0.1448903	total: 8.92s	remaining: 1.86s
# 827:	learn: 0.1448880	total: 8.93s	remaining: 1.85s
# 828:	learn: 0.1448848	total: 8.94s	remaining: 1.84s
# 829:	learn: 0.1448807	total: 8.95s	remaining: 1.83s
# 830:	learn: 0.1448775	total: 8.96s	remaining: 1.82s
# 831:	learn: 0.1448737	total: 8.97s	remaining: 1.81s
# 832:	learn: 0.1448696	total: 8.98s	remaining: 1.8s
# 833:	learn: 0.1448668	total: 8.99s	remaining: 1.79s
# 834:	learn: 0.1448626	total: 9s	remaining: 1.78s
# 835:	learn: 0.1448591	total: 9.01s	remaining: 1.77s
# 836:	learn: 0.1448544	total: 9.02s	remaining: 1.76s
# 837:	learn: 0.1448506	total: 9.03s	remaining: 1.75s
# 838:	learn: 0.1448470	total: 9.04s	remaining: 1.74s
# 839:	learn: 0.1448430	total: 9.05s	remaining: 1.72s
# 840:	learn: 0.1448406	total: 9.06s	remaining: 1.71s
# 841:	learn: 0.1448388	total: 9.08s	remaining: 1.7s
# 842:	learn: 0.1448361	total: 9.09s	remaining: 1.69s
# 843:	learn: 0.1448321	total: 9.1s	remaining: 1.68s
# 844:	learn: 0.1448282	total: 9.12s	remaining: 1.67s
# 845:	learn: 0.1448230	total: 9.13s	remaining: 1.66s
# 846:	learn: 0.1448186	total: 9.14s	remaining: 1.65s
# 847:	learn: 0.1448155	total: 9.16s	remaining: 1.64s
# 848:	learn: 0.1448109	total: 9.17s	remaining: 1.63s
# 849:	learn: 0.1448083	total: 9.18s	remaining: 1.62s
# 850:	learn: 0.1448060	total: 9.19s	remaining: 1.61s
# 851:	learn: 0.1448027	total: 9.2s	remaining: 1.6s
# 852:	learn: 0.1447973	total: 9.21s	remaining: 1.59s
# 853:	learn: 0.1447944	total: 9.22s	remaining: 1.58s
# 854:	learn: 0.1447910	total: 9.24s	remaining: 1.57s
# 855:	learn: 0.1447885	total: 9.25s	remaining: 1.55s
# 856:	learn: 0.1447851	total: 9.26s	remaining: 1.54s
# 857:	learn: 0.1447812	total: 9.27s	remaining: 1.53s
# 858:	learn: 0.1447787	total: 9.28s	remaining: 1.52s
# 859:	learn: 0.1447741	total: 9.29s	remaining: 1.51s
# 860:	learn: 0.1447716	total: 9.3s	remaining: 1.5s
# 861:	learn: 0.1447694	total: 9.32s	remaining: 1.49s
# 862:	learn: 0.1447661	total: 9.33s	remaining: 1.48s
# 863:	learn: 0.1447620	total: 9.34s	remaining: 1.47s
# 864:	learn: 0.1447588	total: 9.35s	remaining: 1.46s
# 865:	learn: 0.1447564	total: 9.36s	remaining: 1.45s
# 866:	learn: 0.1447540	total: 9.37s	remaining: 1.44s
# 867:	learn: 0.1447489	total: 9.38s	remaining: 1.43s
# 868:	learn: 0.1447461	total: 9.39s	remaining: 1.42s
# 869:	learn: 0.1447423	total: 9.4s	remaining: 1.4s
# 870:	learn: 0.1447378	total: 9.41s	remaining: 1.39s
# 871:	learn: 0.1447330	total: 9.42s	remaining: 1.38s
# 872:	learn: 0.1447272	total: 9.43s	remaining: 1.37s
# 873:	learn: 0.1447226	total: 9.44s	remaining: 1.36s
# 874:	learn: 0.1447193	total: 9.45s	remaining: 1.35s
# 875:	learn: 0.1447143	total: 9.46s	remaining: 1.34s
# 876:	learn: 0.1447102	total: 9.47s	remaining: 1.33s
# 877:	learn: 0.1447070	total: 9.48s	remaining: 1.32s
# 878:	learn: 0.1447030	total: 9.49s	remaining: 1.31s
# 879:	learn: 0.1446986	total: 9.5s	remaining: 1.29s
# 880:	learn: 0.1446920	total: 9.51s	remaining: 1.28s
# 881:	learn: 0.1446897	total: 9.52s	remaining: 1.27s
# 882:	learn: 0.1446866	total: 9.54s	remaining: 1.26s
# 883:	learn: 0.1446829	total: 9.55s	remaining: 1.25s
# 884:	learn: 0.1446806	total: 9.57s	remaining: 1.24s
# 885:	learn: 0.1446781	total: 9.58s	remaining: 1.23s
# 886:	learn: 0.1446752	total: 9.59s	remaining: 1.22s
# 887:	learn: 0.1446716	total: 9.61s	remaining: 1.21s
# 888:	learn: 0.1446684	total: 9.62s	remaining: 1.2s
# 889:	learn: 0.1446652	total: 9.63s	remaining: 1.19s
# 890:	learn: 0.1446633	total: 9.64s	remaining: 1.18s
# 891:	learn: 0.1446610	total: 9.65s	remaining: 1.17s
# 892:	learn: 0.1446564	total: 9.66s	remaining: 1.16s
# 893:	learn: 0.1446535	total: 9.67s	remaining: 1.15s
# 894:	learn: 0.1446483	total: 9.68s	remaining: 1.14s
# 895:	learn: 0.1446459	total: 9.69s	remaining: 1.12s
# 896:	learn: 0.1446415	total: 9.7s	remaining: 1.11s
# 897:	learn: 0.1446388	total: 9.71s	remaining: 1.1s
# 898:	learn: 0.1446359	total: 9.72s	remaining: 1.09s
# 899:	learn: 0.1446331	total: 9.73s	remaining: 1.08s
# 900:	learn: 0.1446291	total: 9.74s	remaining: 1.07s
# 901:	learn: 0.1446248	total: 9.76s	remaining: 1.06s
# 902:	learn: 0.1446208	total: 9.77s	remaining: 1.05s
# 903:	learn: 0.1446172	total: 9.78s	remaining: 1.04s
# 904:	learn: 0.1446123	total: 9.78s	remaining: 1.03s
# 905:	learn: 0.1446066	total: 9.79s	remaining: 1.02s
# 906:	learn: 0.1446022	total: 9.8s	remaining: 1s
# 907:	learn: 0.1446003	total: 9.81s	remaining: 994ms
# 908:	learn: 0.1445978	total: 9.82s	remaining: 983ms
# 909:	learn: 0.1445896	total: 9.83s	remaining: 972ms
# 910:	learn: 0.1445876	total: 9.84s	remaining: 962ms
# 911:	learn: 0.1445825	total: 9.85s	remaining: 951ms
# 912:	learn: 0.1445795	total: 9.86s	remaining: 940ms
# 913:	learn: 0.1445765	total: 9.87s	remaining: 929ms
# 914:	learn: 0.1445747	total: 9.89s	remaining: 918ms
# 915:	learn: 0.1445728	total: 9.89s	remaining: 907ms
# 916:	learn: 0.1445692	total: 9.9s	remaining: 897ms
# 917:	learn: 0.1445661	total: 9.92s	remaining: 886ms
# 918:	learn: 0.1445639	total: 9.93s	remaining: 875ms
# 919:	learn: 0.1445599	total: 9.94s	remaining: 864ms
# 920:	learn: 0.1445557	total: 9.95s	remaining: 854ms
# 921:	learn: 0.1445533	total: 9.96s	remaining: 843ms
# 922:	learn: 0.1445477	total: 9.98s	remaining: 833ms
# 923:	learn: 0.1445436	total: 9.99s	remaining: 822ms
# 924:	learn: 0.1445404	total: 10s	remaining: 811ms
# 925:	learn: 0.1445373	total: 10s	remaining: 801ms
# 926:	learn: 0.1445325	total: 10s	remaining: 790ms
# 927:	learn: 0.1445283	total: 10s	remaining: 779ms
# 928:	learn: 0.1445244	total: 10.1s	remaining: 768ms
# 929:	learn: 0.1445195	total: 10.1s	remaining: 758ms
# 930:	learn: 0.1445118	total: 10.1s	remaining: 747ms
# 931:	learn: 0.1445098	total: 10.1s	remaining: 736ms
# 932:	learn: 0.1445076	total: 10.1s	remaining: 725ms
# 933:	learn: 0.1445040	total: 10.1s	remaining: 714ms
# 934:	learn: 0.1445027	total: 10.1s	remaining: 703ms
# 935:	learn: 0.1444996	total: 10.1s	remaining: 692ms
# 936:	learn: 0.1444940	total: 10.1s	remaining: 681ms
# 937:	learn: 0.1444918	total: 10.1s	remaining: 671ms
# 938:	learn: 0.1444858	total: 10.2s	remaining: 660ms
# 939:	learn: 0.1444801	total: 10.2s	remaining: 649ms
# 940:	learn: 0.1444771	total: 10.2s	remaining: 638ms
# 941:	learn: 0.1444731	total: 10.2s	remaining: 627ms
# 942:	learn: 0.1444696	total: 10.2s	remaining: 616ms
# 943:	learn: 0.1444672	total: 10.2s	remaining: 605ms
# 944:	learn: 0.1444631	total: 10.2s	remaining: 594ms
# 945:	learn: 0.1444588	total: 10.2s	remaining: 583ms
# 946:	learn: 0.1444544	total: 10.2s	remaining: 572ms
# 947:	learn: 0.1444498	total: 10.2s	remaining: 562ms
# 948:	learn: 0.1444443	total: 10.2s	remaining: 551ms
# 949:	learn: 0.1444376	total: 10.3s	remaining: 540ms
# 950:	learn: 0.1444322	total: 10.3s	remaining: 529ms
# 951:	learn: 0.1444274	total: 10.3s	remaining: 518ms
# 952:	learn: 0.1444244	total: 10.3s	remaining: 507ms
# 953:	learn: 0.1444213	total: 10.3s	remaining: 497ms
# 954:	learn: 0.1444171	total: 10.3s	remaining: 486ms
# 955:	learn: 0.1444132	total: 10.3s	remaining: 475ms
# 956:	learn: 0.1444104	total: 10.3s	remaining: 464ms
# 957:	learn: 0.1444036	total: 10.3s	remaining: 453ms
# 958:	learn: 0.1444001	total: 10.4s	remaining: 443ms
# 959:	learn: 0.1443961	total: 10.4s	remaining: 432ms
# 960:	learn: 0.1443903	total: 10.4s	remaining: 421ms
# 961:	learn: 0.1443859	total: 10.4s	remaining: 411ms
# 962:	learn: 0.1443830	total: 10.4s	remaining: 400ms
# 963:	learn: 0.1443777	total: 10.4s	remaining: 389ms
# 964:	learn: 0.1443739	total: 10.4s	remaining: 379ms
# 965:	learn: 0.1443701	total: 10.4s	remaining: 368ms
# 966:	learn: 0.1443641	total: 10.5s	remaining: 357ms
# 967:	learn: 0.1443607	total: 10.5s	remaining: 346ms
# 968:	learn: 0.1443557	total: 10.5s	remaining: 335ms
# 969:	learn: 0.1443514	total: 10.5s	remaining: 324ms
# 970:	learn: 0.1443486	total: 10.5s	remaining: 314ms
# 971:	learn: 0.1443458	total: 10.5s	remaining: 303ms
# 972:	learn: 0.1443408	total: 10.5s	remaining: 292ms
# 973:	learn: 0.1443364	total: 10.5s	remaining: 281ms
# 974:	learn: 0.1443330	total: 10.5s	remaining: 270ms
# 975:	learn: 0.1443296	total: 10.6s	remaining: 260ms
# 976:	learn: 0.1443260	total: 10.6s	remaining: 249ms
# 977:	learn: 0.1443224	total: 10.6s	remaining: 238ms
# 978:	learn: 0.1443188	total: 10.6s	remaining: 227ms
# 979:	learn: 0.1443165	total: 10.6s	remaining: 216ms
# 980:	learn: 0.1443158	total: 10.6s	remaining: 205ms
# 981:	learn: 0.1443138	total: 10.6s	remaining: 195ms
# 982:	learn: 0.1443096	total: 10.6s	remaining: 184ms
# 983:	learn: 0.1443084	total: 10.6s	remaining: 173ms
# 984:	learn: 0.1443052	total: 10.6s	remaining: 162ms
# 985:	learn: 0.1443007	total: 10.7s	remaining: 151ms
# 986:	learn: 0.1442989	total: 10.7s	remaining: 140ms
# 987:	learn: 0.1442940	total: 10.7s	remaining: 130ms
# 988:	learn: 0.1442907	total: 10.7s	remaining: 119ms
# 989:	learn: 0.1442839	total: 10.7s	remaining: 108ms
# 990:	learn: 0.1442804	total: 10.7s	remaining: 97.2ms
# 991:	learn: 0.1442780	total: 10.7s	remaining: 86.4ms
# 992:	learn: 0.1442744	total: 10.7s	remaining: 75.6ms
# 993:	learn: 0.1442699	total: 10.7s	remaining: 64.8ms
# 994:	learn: 0.1442650	total: 10.7s	remaining: 54ms
# 995:	learn: 0.1442611	total: 10.8s	remaining: 43.2ms
# 996:	learn: 0.1442565	total: 10.8s	remaining: 32.4ms
# 997:	learn: 0.1442516	total: 10.8s	remaining: 21.6ms
# 998:	learn: 0.1442483	total: 10.8s	remaining: 10.8ms
# 999:	learn: 0.1442448	total: 10.8s	remaining: 0us
# Submission file created: submission.csv

# %%
import joblib

# After training the model
joblib.dump(meta_model, 'loan_model.pkl')  # Save the trained model
# Out:
# ['loan_model.pkl']

# %%
import tkinter as tk
from tkinter import messagebox
import joblib
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# Load the trained model
model = joblib.load('loan_model.pkl')

# Function to preprocess user input data
def preprocess_user_input(data):
    # Create a DataFrame from the input data
    df = pd.DataFrame([data])
    #print(df.head())
    # Label Encoding categorical columns
    #cat_columns = ['person_home_ownership', 'loan_intent', 'loan_grade']
    #for col in cat_columns:
        #le = LabelEncoder()
        #df[col] = le.fit_transform(df[col])

    # Standardize the data
    #scaler = StandardScaler()
    #df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)
    print(df.head())
    return df

# Function to predict loan eligibility
def predict_loan():
    try:
        # Collecting the data from GUI inputs
        person_age = int(age_entry.get())
        person_income = int(income_entry.get())
        person_emp_length = float(emp_length_entry.get())
        loan_amnt = float(loan_amnt_entry.get())
        loan_int_rate = float(loan_int_rate_entry.get())
        loan_percent_income = float(loan_percent_income_entry.get())
        home_ownership = home_ownership_var.get()
        loan_intent = loan_intent_var.get()
        loan_grade = loan_grade_var.get()

        # Create the input data dictionary
        input_data = {
            'person_age': person_age,
            'person_income': person_income,
            'person_emp_length': person_emp_length,
            'loan_amnt': loan_amnt,
            'loan_int_rate': loan_int_rate,
            'loan_percent_income': loan_percent_income,
            'person_home_ownership': home_ownership,
            'loan_intent': loan_intent,
            'loan_grade': loan_grade,
        }

        # Preprocess the data
        preprocessed_data = preprocess_user_input(input_data)

        # Make the prediction
        prediction = model.predict(preprocessed_data)[0]

        # Display result
        if prediction > 0.1:
            messagebox.showinfo("Loan Status", "Congratulations! You are eligible for the loan.")
        else:
            messagebox.showinfo("Loan Status", "Sorry, you are not eligible for the loan. Prediction: "+str(prediction))
    except ValueError:
        messagebox.showerror("Input Error", "Please enter valid numerical values.")

# Create main window
root = tk.Tk()
root.title("Loan Eligibility Prediction")

# Create and place labels and entry widgets
tk.Label(root, text="Age:").grid(row=0, column=0)
age_entry = tk.Entry(root)
age_entry.grid(row=0, column=1)

tk.Label(root, text="Income:").grid(row=1, column=0)
income_entry = tk.Entry(root)
income_entry.grid(row=1, column=1)

tk.Label(root, text="Employment Length (in years):").grid(row=2, column=0)
emp_length_entry = tk.Entry(root)
emp_length_entry.grid(row=2, column=1)

tk.Label(root, text="Loan Amount:").grid(row=3, column=0)
loan_amnt_entry = tk.Entry(root)
loan_amnt_entry.grid(row=3, column=1)

tk.Label(root, text="Loan Interest Rate (%):").grid(row=4, column=0)
loan_int_rate_entry = tk.Entry(root)
loan_int_rate_entry.grid(row=4, column=1)

tk.Label(root, text="Loan Percent of Income:").grid(row=5, column=0)
loan_percent_income_entry = tk.Entry(root)
loan_percent_income_entry.grid(row=5, column=1)

tk.Label(root, text="Home Ownership:").grid(row=6, column=0)
home_ownership_var = tk.StringVar()
home_ownership_var.set("1")  # Default value
home_ownership_menu = tk.OptionMenu(root, home_ownership_var, "1", "2", "3")
home_ownership_menu.grid(row=6, column=1)

tk.Label(root, text="Loan Intent:").grid(row=7, column=0)
loan_intent_var = tk.StringVar()
loan_intent_var.set("1")  # Default value
loan_intent_menu = tk.OptionMenu(root, loan_intent_var, "1", "2", "3", "4", "5")
loan_intent_menu.grid(row=7, column=1)

tk.Label(root, text="Loan Grade:").grid(row=8, column=0)
loan_grade_var = tk.StringVar()
loan_grade_var.set("1")  # Default value
loan_grade_menu = tk.OptionMenu(root, loan_grade_var, "1", "2", "3", "4", "5", "6")
loan_grade_menu.grid(row=8, column=1)

# Prediction button
predict_button = tk.Button(root, text="Check Loan Eligibility", command=predict_loan)
predict_button.grid(row=9, column=0, columnspan=2)

# Run the GUI
root.mainloop()
